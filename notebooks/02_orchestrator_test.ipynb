# %% [markdown]
# # 02 — Orchestrator POC
#
# ```python
# import asyncio
# from src.core.orchestrator import AgenticOrchestrator
#
# async def main():
#     state = await AgenticOrchestrator().run("Test question")
#     print(state)
#
# asyncio.run(main())
# ```
